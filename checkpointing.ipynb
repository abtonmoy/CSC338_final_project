# %% [markdown]
# Import Libraries and Load Dataset

# %%
class SaveEveryNEpochs(tf.keras.callbacks.Callback):
    def __init__(self, n, filepath):
        super().__init__()
        self.n = n
        self.filepath = filepath

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.n == 0:
            path = self.filepath.format(epoch=epoch + 1)
            self.model.save_weights(path)
            print(f"\nSaved weights at: {path}")

# %%
checkpoint_dir = "checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

def get_latest_checkpoint():
    # Look for files like epoch_0010.weights.h5
    pattern = os.path.join(checkpoint_dir, "epoch_*.weights.h5")
    files = glob.glob(pattern)
    if not files:
        return None, 0  # no checkpoint found

    # Extract the epoch number using regex
    def extract_epoch(path):
        match = re.search(r"epoch_(\d+)\.weights\.h5", path)
        return int(match.group(1)) if match else -1

    latest_file = max(files, key=extract_epoch)
    latest_epoch = extract_epoch(latest_file)
    return latest_file, latest_epoch

# %%
checkpoint_cb = SaveEveryNEpochs(
    n=1,
    filepath="checkpoints/epoch_{epoch:04d}.weights.h5"
)

# %%
latest_ckpt, last_epoch = get_latest_checkpoint()
print("Latest checkpoint:", latest_ckpt)
print("Last epoch number:", last_epoch)
# Out:
# Latest checkpoint: checkpoints/epoch_0300.weights.h5
# Last epoch number: 300

# %%
# model = PUT THE CODE HERE THAT DEFINES YOUR MODEL



# Load weights if checkpoint exists
if latest_ckpt is not None:
    print(f"Loading weights from {latest_ckpt}")
    model.load_weights(latest_ckpt)
else:
    print("No checkpoint found; starting from scratch.")

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=masked_loss,            # custom loss that ignores padding
    metrics=[masked_accuracy],   # custom accuracy that ignores padding
)

model.summary()
# Out:
# /opt/anaconda3/envs/tf216metal/lib/python3.11/site-packages/keras/src/layers/layer.py:970: UserWarning: Layer 'positional_embedding' (of type SinusoidalPositionalEncoding) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Loading weights from checkpoints/epoch_0300.weights.h5
# Model: "DadLLM"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ token_ids           │ (None, 64)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ token_embedding     │ (None, 64, 768)   │ 30,720,000 │ token_ids[0][0]   │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_embeddi… │ (None, 64, 768)   │          0 │ token_embedding[… │
# │ (SinusoidalPositio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_1               │ (None, 64, 768)   │  2,362,368 │ positional_embed… │
# │ (MultiHeadAttentio… │                   │            │ positional_embed… │
# │                     │                   │            │ positional_embed… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 768)   │          0 │ positional_embed… │
# │                     │                   │            │ mha_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_1           │ (None, 64, 768)   │      1,536 │ add[0][0]         │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_1 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_1 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 768)   │          0 │ ln_attn_1[0][0],  │
# │                     │                   │            │ ffn2_1[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_1            │ (None, 64, 768)   │      1,536 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_2               │ (None, 64, 768)   │  2,362,368 │ ln_ffn_1[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_1[0][0],   │
# │                     │                   │            │ ln_ffn_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 64, 768)   │          0 │ ln_ffn_1[0][0],   │
# │                     │                   │            │ mha_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_2           │ (None, 64, 768)   │      1,536 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_2 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_2 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 64, 768)   │          0 │ ln_attn_2[0][0],  │
# │                     │                   │            │ ffn2_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_2            │ (None, 64, 768)   │      1,536 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_3               │ (None, 64, 768)   │  2,362,368 │ ln_ffn_2[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_2[0][0],   │
# │                     │                   │            │ ln_ffn_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 64, 768)   │          0 │ ln_ffn_2[0][0],   │
# │                     │                   │            │ mha_3[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_3           │ (None, 64, 768)   │      1,536 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_3 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_3 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 64, 768)   │          0 │ ln_attn_3[0][0],  │
# │                     │                   │            │ ffn2_3[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_3            │ (None, 64, 768)   │      1,536 │ add_5[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_4               │ (None, 64, 768)   │  2,362,368 │ ln_ffn_3[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_3[0][0],   │
# │                     │                   │            │ ln_ffn_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 64, 768)   │          0 │ ln_ffn_3[0][0],   │
# │                     │                   │            │ mha_4[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_4           │ (None, 64, 768)   │      1,536 │ add_6[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_4 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_4 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 64, 768)   │          0 │ ln_attn_4[0][0],  │
# │                     │                   │            │ ffn2_4[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_4            │ (None, 64, 768)   │      1,536 │ add_7[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_5               │ (None, 64, 768)   │  2,362,368 │ ln_ffn_4[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_4[0][0],   │
# │                     │                   │            │ ln_ffn_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 64, 768)   │          0 │ ln_ffn_4[0][0],   │
# │                     │                   │            │ mha_5[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_5           │ (None, 64, 768)   │      1,536 │ add_8[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_5 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_5 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_9 (Add)         │ (None, 64, 768)   │          0 │ ln_attn_5[0][0],  │
# │                     │                   │            │ ffn2_5[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_5            │ (None, 64, 768)   │      1,536 │ add_9[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_6               │ (None, 64, 768)   │  2,362,368 │ ln_ffn_5[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_5[0][0],   │
# │                     │                   │            │ ln_ffn_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_10 (Add)        │ (None, 64, 768)   │          0 │ ln_ffn_5[0][0],   │
# │                     │                   │            │ mha_6[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_6           │ (None, 64, 768)   │      1,536 │ add_10[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_6 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_6 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_11 (Add)        │ (None, 64, 768)   │          0 │ ln_attn_6[0][0],  │
# │                     │                   │            │ ffn2_6[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_6            │ (None, 64, 768)   │      1,536 │ add_11[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_7               │ (None, 64, 768)   │  2,362,368 │ ln_ffn_6[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_6[0][0],   │
# │                     │                   │            │ ln_ffn_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 64, 768)   │          0 │ ln_ffn_6[0][0],   │
# │                     │                   │            │ mha_7[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_7           │ (None, 64, 768)   │      1,536 │ add_12[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_7 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_7 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_7[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 64, 768)   │          0 │ ln_attn_7[0][0],  │
# │                     │                   │            │ ffn2_7[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_7            │ (None, 64, 768)   │      1,536 │ add_13[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_8               │ (None, 64, 768)   │  2,362,368 │ ln_ffn_7[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_7[0][0],   │
# │                     │                   │            │ ln_ffn_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 64, 768)   │          0 │ ln_ffn_7[0][0],   │
# │                     │                   │            │ mha_8[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_8           │ (None, 64, 768)   │      1,536 │ add_14[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_8 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_8[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_8 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_8[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 64, 768)   │          0 │ ln_attn_8[0][0],  │
# │                     │                   │            │ ffn2_8[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_8            │ (None, 64, 768)   │      1,536 │ add_15[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_9               │ (None, 64, 768)   │  2,362,368 │ ln_ffn_8[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_8[0][0],   │
# │                     │                   │            │ ln_ffn_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 64, 768)   │          0 │ ln_ffn_8[0][0],   │
# │                     │                   │            │ mha_9[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_9           │ (None, 64, 768)   │      1,536 │ add_16[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_9 (Dense)      │ (None, 64, 3072)  │  2,362,368 │ ln_attn_9[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_9 (Dense)      │ (None, 64, 768)   │  2,360,064 │ ffn1_9[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 64, 768)   │          0 │ ln_attn_9[0][0],  │
# │                     │                   │            │ ffn2_9[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_9            │ (None, 64, 768)   │      1,536 │ add_17[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_10              │ (None, 64, 768)   │  2,362,368 │ ln_ffn_9[0][0],   │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_9[0][0],   │
# │                     │                   │            │ ln_ffn_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 64, 768)   │          0 │ ln_ffn_9[0][0],   │
# │                     │                   │            │ mha_10[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_10          │ (None, 64, 768)   │      1,536 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_10 (Dense)     │ (None, 64, 3072)  │  2,362,368 │ ln_attn_10[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_10 (Dense)     │ (None, 64, 768)   │  2,360,064 │ ffn1_10[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 64, 768)   │          0 │ ln_attn_10[0][0], │
# │                     │                   │            │ ffn2_10[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_10           │ (None, 64, 768)   │      1,536 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_11              │ (None, 64, 768)   │  2,362,368 │ ln_ffn_10[0][0],  │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_10[0][0],  │
# │                     │                   │            │ ln_ffn_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 64, 768)   │          0 │ ln_ffn_10[0][0],  │
# │                     │                   │            │ mha_11[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_11          │ (None, 64, 768)   │      1,536 │ add_20[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_11 (Dense)     │ (None, 64, 3072)  │  2,362,368 │ ln_attn_11[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_11 (Dense)     │ (None, 64, 768)   │  2,360,064 │ ffn1_11[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 64, 768)   │          0 │ ln_attn_11[0][0], │
# │                     │                   │            │ ffn2_11[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_11           │ (None, 64, 768)   │      1,536 │ add_21[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mha_12              │ (None, 64, 768)   │  2,362,368 │ ln_ffn_11[0][0],  │
# │ (MultiHeadAttentio… │                   │            │ ln_ffn_11[0][0],  │
# │                     │                   │            │ ln_ffn_11[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 64, 768)   │          0 │ ln_ffn_11[0][0],  │
# │                     │                   │            │ mha_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_attn_12          │ (None, 64, 768)   │      1,536 │ add_22[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn1_12 (Dense)     │ (None, 64, 3072)  │  2,362,368 │ ln_attn_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ffn2_12 (Dense)     │ (None, 64, 768)   │  2,360,064 │ ffn1_12[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 64, 768)   │          0 │ ln_attn_12[0][0], │
# │                     │                   │            │ ffn2_12[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_ffn_12           │ (None, 64, 768)   │      1,536 │ add_23[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lm_head (Dense)     │ (None, 64, 40000) │ 30,760,000 │ ln_ffn_12[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 146,534,464 (558.98 MB)
#  Trainable params: 146,534,464 (558.98 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    # put stuff here about your test and validation data
    epochs=50,                 # total desired epochs
    # If your last weights saved was epoch 25, and you have epochs=50
    # Then retraining will only do 25 new epochs.
    initial_epoch=last_epoch,  # resume here
    callbacks=[checkpoint_cb],
)
# Out:
# Epoch 251/300
# W0000 00:00:1765330762.814225    6463 assert_op.cc:38] Ignoring Assert operator compile_loss/masked_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.3139 - masked_accuracy: 0.9152
# W0000 00:00:1765331061.684052    6463 assert_op.cc:38] Ignoring Assert operator compile_loss/masked_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.3139 - masked_accuracy: 0.9152
# W0000 00:00:1765331076.880793    6466 assert_op.cc:38] Ignoring Assert operator compile_loss/masked_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# W0000 00:00:1765331086.824801    6466 assert_op.cc:38] Ignoring Assert operator compile_loss/masked_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# Saved weights at: checkpoints/epoch_0251.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 339s 84ms/step - loss: 0.2985 - masked_accuracy: 0.9201 - val_loss: 0.8266 - val_masked_accuracy: 0.8691
# Epoch 252/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3131 - masked_accuracy: 0.9148
# Saved weights at: checkpoints/epoch_0252.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 271s 73ms/step - loss: 0.2968 - masked_accuracy: 0.9198 - val_loss: 0.8177 - val_masked_accuracy: 0.8714
# Epoch 253/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3114 - masked_accuracy: 0.9151
# Saved weights at: checkpoints/epoch_0253.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 271s 73ms/step - loss: 0.2954 - masked_accuracy: 0.9201 - val_loss: 0.8261 - val_masked_accuracy: 0.8685
# Epoch 254/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3116 - masked_accuracy: 0.9149
# Saved weights at: checkpoints/epoch_0254.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 271s 73ms/step - loss: 0.2955 - masked_accuracy: 0.9200 - val_loss: 0.8183 - val_masked_accuracy: 0.8697
# Epoch 255/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3113 - masked_accuracy: 0.9149
# Saved weights at: checkpoints/epoch_0255.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 271s 73ms/step - loss: 0.2951 - masked_accuracy: 0.9200 - val_loss: 0.8197 - val_masked_accuracy: 0.8704
# Epoch 256/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3108 - masked_accuracy: 0.9150
# Saved weights at: checkpoints/epoch_0256.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2949 - masked_accuracy: 0.9201 - val_loss: 0.8178 - val_masked_accuracy: 0.8695
# Epoch 257/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3103 - masked_accuracy: 0.9150
# Saved weights at: checkpoints/epoch_0257.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 271s 73ms/step - loss: 0.2949 - masked_accuracy: 0.9199 - val_loss: 0.8197 - val_masked_accuracy: 0.8698
# Epoch 258/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3109 - masked_accuracy: 0.9151
# Saved weights at: checkpoints/epoch_0258.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2949 - masked_accuracy: 0.9200 - val_loss: 0.8207 - val_masked_accuracy: 0.8709
# Epoch 259/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3101 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0259.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2946 - masked_accuracy: 0.9202 - val_loss: 0.8177 - val_masked_accuracy: 0.8690
# Epoch 260/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3099 - masked_accuracy: 0.9152
# Saved weights at: checkpoints/epoch_0260.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2942 - masked_accuracy: 0.9202 - val_loss: 0.8249 - val_masked_accuracy: 0.8703
# Epoch 261/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3110 - masked_accuracy: 0.9149
# Saved weights at: checkpoints/epoch_0261.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2947 - masked_accuracy: 0.9200 - val_loss: 0.8116 - val_masked_accuracy: 0.8706
# Epoch 262/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3100 - masked_accuracy: 0.9151
# Saved weights at: checkpoints/epoch_0262.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2947 - masked_accuracy: 0.9201 - val_loss: 0.8303 - val_masked_accuracy: 0.8682
# Epoch 263/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3101 - masked_accuracy: 0.9152
# Saved weights at: checkpoints/epoch_0263.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2943 - masked_accuracy: 0.9202 - val_loss: 0.8195 - val_masked_accuracy: 0.8677
# Epoch 264/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3103 - masked_accuracy: 0.9151
# Saved weights at: checkpoints/epoch_0264.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2945 - masked_accuracy: 0.9202 - val_loss: 0.8209 - val_masked_accuracy: 0.8708
# Epoch 265/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3098 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0265.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2941 - masked_accuracy: 0.9203 - val_loss: 0.8242 - val_masked_accuracy: 0.8684
# Epoch 266/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3099 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0266.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2940 - masked_accuracy: 0.9203 - val_loss: 0.8238 - val_masked_accuracy: 0.8693
# Epoch 267/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3102 - masked_accuracy: 0.9150
# Saved weights at: checkpoints/epoch_0267.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2941 - masked_accuracy: 0.9202 - val_loss: 0.8300 - val_masked_accuracy: 0.8702
# Epoch 268/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3092 - masked_accuracy: 0.9155
# Saved weights at: checkpoints/epoch_0268.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2937 - masked_accuracy: 0.9204 - val_loss: 0.8346 - val_masked_accuracy: 0.8692
# Epoch 269/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3094 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0269.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2940 - masked_accuracy: 0.9203 - val_loss: 0.8171 - val_masked_accuracy: 0.8689
# Epoch 270/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3094 - masked_accuracy: 0.9154
# Saved weights at: checkpoints/epoch_0270.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2938 - masked_accuracy: 0.9204 - val_loss: 0.8149 - val_masked_accuracy: 0.8695
# Epoch 271/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3100 - masked_accuracy: 0.9151
# Saved weights at: checkpoints/epoch_0271.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2939 - masked_accuracy: 0.9202 - val_loss: 0.8304 - val_masked_accuracy: 0.8671
# Epoch 272/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3091 - masked_accuracy: 0.9154
# Saved weights at: checkpoints/epoch_0272.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2939 - masked_accuracy: 0.9203 - val_loss: 0.8291 - val_masked_accuracy: 0.8702
# Epoch 273/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.3100 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0273.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2935 - masked_accuracy: 0.9204 - val_loss: 0.8322 - val_masked_accuracy: 0.8693
# Epoch 274/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3094 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0274.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2938 - masked_accuracy: 0.9202 - val_loss: 0.8304 - val_masked_accuracy: 0.8679
# Epoch 275/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.3096 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0275.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 283s 76ms/step - loss: 0.2939 - masked_accuracy: 0.9203 - val_loss: 0.8327 - val_masked_accuracy: 0.8681
# Epoch 276/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.3099 - masked_accuracy: 0.9152
# Saved weights at: checkpoints/epoch_0276.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 278s 75ms/step - loss: 0.2940 - masked_accuracy: 0.9202 - val_loss: 0.8233 - val_masked_accuracy: 0.8690
# Epoch 277/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3092 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0277.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 74ms/step - loss: 0.2938 - masked_accuracy: 0.9202 - val_loss: 0.8285 - val_masked_accuracy: 0.8710
# Epoch 278/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3093 - masked_accuracy: 0.9155
# Saved weights at: checkpoints/epoch_0278.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 273s 74ms/step - loss: 0.2939 - masked_accuracy: 0.9204 - val_loss: 0.8300 - val_masked_accuracy: 0.8691
# Epoch 279/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3101 - masked_accuracy: 0.9152
# Saved weights at: checkpoints/epoch_0279.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2939 - masked_accuracy: 0.9203 - val_loss: 0.8273 - val_masked_accuracy: 0.8709
# Epoch 280/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3101 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0280.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2940 - masked_accuracy: 0.9203 - val_loss: 0.8256 - val_masked_accuracy: 0.8689
# Epoch 281/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3090 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0281.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 74ms/step - loss: 0.2934 - masked_accuracy: 0.9203 - val_loss: 0.8172 - val_masked_accuracy: 0.8711
# Epoch 282/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3096 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0282.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2935 - masked_accuracy: 0.9203 - val_loss: 0.8300 - val_masked_accuracy: 0.8689
# Epoch 283/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3082 - masked_accuracy: 0.9157
# Saved weights at: checkpoints/epoch_0283.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 74ms/step - loss: 0.2929 - masked_accuracy: 0.9205 - val_loss: 0.8344 - val_masked_accuracy: 0.8700
# Epoch 284/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3091 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0284.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2933 - masked_accuracy: 0.9205 - val_loss: 0.8300 - val_masked_accuracy: 0.8695
# Epoch 285/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3089 - masked_accuracy: 0.9155
# Saved weights at: checkpoints/epoch_0285.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2932 - masked_accuracy: 0.9204 - val_loss: 0.8207 - val_masked_accuracy: 0.8716
# Epoch 286/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3096 - masked_accuracy: 0.9152
# Saved weights at: checkpoints/epoch_0286.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2932 - masked_accuracy: 0.9204 - val_loss: 0.8328 - val_masked_accuracy: 0.8689
# Epoch 287/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3088 - masked_accuracy: 0.9155
# Saved weights at: checkpoints/epoch_0287.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2935 - masked_accuracy: 0.9203 - val_loss: 0.8321 - val_masked_accuracy: 0.8699
# Epoch 288/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3087 - masked_accuracy: 0.9155
# Saved weights at: checkpoints/epoch_0288.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 74ms/step - loss: 0.2929 - masked_accuracy: 0.9205 - val_loss: 0.8316 - val_masked_accuracy: 0.8702
# Epoch 289/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3095 - masked_accuracy: 0.9154
# Saved weights at: checkpoints/epoch_0289.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2932 - masked_accuracy: 0.9204 - val_loss: 0.8339 - val_masked_accuracy: 0.8704
# Epoch 290/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3089 - masked_accuracy: 0.9154
# Saved weights at: checkpoints/epoch_0290.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 74ms/step - loss: 0.2933 - masked_accuracy: 0.9203 - val_loss: 0.8269 - val_masked_accuracy: 0.8692
# Epoch 291/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3090 - masked_accuracy: 0.9154
# Saved weights at: checkpoints/epoch_0291.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2932 - masked_accuracy: 0.9205 - val_loss: 0.8247 - val_masked_accuracy: 0.8708
# Epoch 292/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3086 - masked_accuracy: 0.9154
# Saved weights at: checkpoints/epoch_0292.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2928 - masked_accuracy: 0.9205 - val_loss: 0.8341 - val_masked_accuracy: 0.8683
# Epoch 293/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3090 - masked_accuracy: 0.9156
# Saved weights at: checkpoints/epoch_0293.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 74ms/step - loss: 0.2929 - masked_accuracy: 0.9205 - val_loss: 0.8220 - val_masked_accuracy: 0.8717
# Epoch 294/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3085 - masked_accuracy: 0.9157
# Saved weights at: checkpoints/epoch_0294.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 273s 74ms/step - loss: 0.2928 - masked_accuracy: 0.9205 - val_loss: 0.8138 - val_masked_accuracy: 0.8721
# Epoch 295/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3083 - masked_accuracy: 0.9156
# Saved weights at: checkpoints/epoch_0295.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2927 - masked_accuracy: 0.9206 - val_loss: 0.8299 - val_masked_accuracy: 0.8707
# Epoch 296/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3084 - masked_accuracy: 0.9157
# Saved weights at: checkpoints/epoch_0296.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 74ms/step - loss: 0.2929 - masked_accuracy: 0.9206 - val_loss: 0.8238 - val_masked_accuracy: 0.8721
# Epoch 297/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3079 - masked_accuracy: 0.9156
# Saved weights at: checkpoints/epoch_0297.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2928 - masked_accuracy: 0.9205 - val_loss: 0.8318 - val_masked_accuracy: 0.8682
# Epoch 298/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3087 - masked_accuracy: 0.9155
# Saved weights at: checkpoints/epoch_0298.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2927 - masked_accuracy: 0.9205 - val_loss: 0.8278 - val_masked_accuracy: 0.8708
# Epoch 299/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3084 - masked_accuracy: 0.9156
# Saved weights at: checkpoints/epoch_0299.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2922 - masked_accuracy: 0.9207 - val_loss: 0.8204 - val_masked_accuracy: 0.8720
# Epoch 300/300
# 3704/3705 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.3090 - masked_accuracy: 0.9153
# Saved weights at: checkpoints/epoch_0300.weights.h5
# 3705/3705 ━━━━━━━━━━━━━━━━━━━━ 272s 73ms/step - loss: 0.2929 - masked_accuracy: 0.9204 - val_loss: 0.8236 - val_masked_accuracy: 0.8716
